# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

np.random.seed(42)

pd.options.display.max_columns = None

# %% [markdown]
# # Get data

# %%
df = pd.read_csv(r"../data/processed/processed.csv")
df['Date'] = pd.to_datetime(df['Date'])
df.index=df['Date']
df.drop(columns=['Date'], inplace=True)
df.dropna(inplace=True)
display(df)
# Out:
#             BDRX_Close  DowJones_Close    Gold_Close  Ibovespa_Close  \
# Date
# 2013-08-02     2011.26    36033.018842   3015.952665         48474.0
# 2013-08-05     2022.45    35658.104653   2975.138345         48436.0
# 2013-08-06     2013.93    35733.451263   2954.696207         47422.0
# 2013-08-07     2009.84    35508.281605   2951.856665         47447.0
# 2013-08-08     2001.47    35709.679833   3019.983757         48929.0
# ...                ...             ...           ...             ...
# 2020-07-27     9933.38   139014.418355  10237.532236        104477.0
# 2020-07-28     9827.49   135626.954163  10026.797032        104109.0
# 2020-07-29     9975.03   136739.828124  10091.809758        105605.0
# 2020-07-30     9897.93   136009.996141  10198.559156        105009.0
# 2020-07-31    10071.73   136208.920061  10276.876600        102912.0
#
#             ICON_Close  IEE_Close  IFIX_Close  IFNC_Close  IGCNM_Close  \
# Date
# 2013-08-02     2345.13   25667.97     1418.52     3912.97      1612.71
# 2013-08-05     2340.01   25822.56     1421.89     3855.36      1605.48
# 2013-08-06     2311.20   25357.78     1411.92     3761.45      1582.97
# 2013-08-07     2297.88   25566.07     1409.43     3755.45      1573.96
# 2013-08-08     2336.10   25954.62     1406.49     3864.92      1602.07
# ...                ...        ...         ...         ...          ...
# 2020-07-27     5028.75   76087.31     2722.77    11204.42      3835.85
# 2020-07-28     5079.07   75458.66     2722.71    11105.66      3831.64
# 2020-07-29     5137.84   75665.49     2723.24    11289.12      3876.78
# 2020-07-30     5189.67   76139.19     2733.65    11118.28      3889.67
# 2020-07-31     5061.51   76523.66     2733.12    10850.73      3836.89
#
#             IGCX_Close  IMAT_Close  IMOB_Close  INDX_Close   IVBX2_Close  \
# Date
# 2013-08-02     7392.28     1561.47      715.73    11716.32   6629.910156
# 2013-08-05     7374.18     1563.34      713.46    11695.72   6635.709961
# 2013-08-06     7248.62     1538.77      695.59    11505.03   6518.899902
# 2013-08-07     7236.46     1563.37      689.40    11501.99   6502.629883
# 2013-08-08     7390.59     1600.83      703.92    11715.90   6630.509766
# ...                ...         ...         ...         ...           ...
# 2020-07-27    16864.23     3694.88     1032.32    19847.30  14701.179688
# 2020-07-28    16806.86     3666.32     1033.11    19776.78  14759.269531
# 2020-07-29    17034.39     3726.43     1058.39    20008.63  14905.910156
# 2020-07-30    17020.89     3700.46     1064.93    19968.75  15049.860352
# 2020-07-31    16743.19     3649.56     1045.54    19523.91  14857.469727
#
#             Nasdaq_Close     S&P_Close  selic_Close  SMAL11-ETF_Close  \
# Date
# 2013-08-02   8490.484711   3934.292705         8.40         64.180000
# 2013-08-05   8434.697688   3899.107794         8.40         64.180000
# 2013-08-06   8440.802048   3908.364150         8.40         63.110001
# 2013-08-07   8386.683775   3880.976710         8.40         62.590000
# 2013-08-08   8454.019662   3911.163622         8.40         63.919998
# ...                  ...           ...          ...               ...
# 2020-07-27  55095.207005  16939.198371         2.15        117.510002
# 2020-07-28  53481.512766  16547.351481         2.15        118.699997
# 2020-07-29  54320.391977  16788.460108         2.15        119.809998
# 2020-07-30  54726.270105  16779.061786         2.15        120.690002
# 2020-07-31  55380.044636  16859.025971         2.15        118.000000
#
#             USDBRL_Close  UTIL_Close   Vix_Close
# Date
# 2013-08-02       2.30120     2614.79   27.568376
# 2013-08-05       2.28400     2629.09   27.042560
# 2013-08-06       2.30260     2587.04   29.289072
# 2013-08-07       2.29520     2609.28   29.791696
# 2013-08-08       2.30410     2635.92   29.331193
# ...                  ...         ...         ...
# 2020-07-27       5.22910     8413.50  129.367934
# 2020-07-28       5.14142     8350.41  130.797730
# 2020-07-29       5.15230     8344.93  124.170430
# 2020-07-30       5.16880     8416.10  127.979488
# 2020-07-31       5.15390     8448.01  126.064389
#
# [1666 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['BDRX_Close', 'DowJones_Close', 'Gold_Close', 'Ibovespa_Close',
#        'ICON_Close', 'IEE_Close', 'IFIX_Close', 'IFNC_Close', 'IGCNM_Close',
#        'IGCX_Close', 'IMAT_Close', 'IMOB_Close', 'INDX_Close', 'IVBX2_Close',
#        'Nasdaq_Close', 'S&P_Close', 'selic_Close', 'SMAL11-ETF_Close',
#        'USDBRL_Close', 'UTIL_Close', 'Vix_Close'],
#       dtype='object')

# %%
df = df[['DowJones_Close', 'Gold_Close', 'Ibovespa_Close',
       'IFIX_Close','S&P_Close','USDBRL_Close','selic_Close']]

# %% [markdown]
# # Calculate returns

# %%
df = df/df.shift(1)
df['selic_Close'] = df['selic_Close']**(1/365)

# %% [markdown]
# # Create dataframe with portfolios

# %% [markdown]
# ## Number of portfolios

# %%
num_port = 100000

# %% [markdown]
# ## Creates dataframe with random values and normalizes rows to sum 1

# %%
df_port = pd.DataFrame(columns=list(df.columns),
                       data = np.random.uniform(size=(num_port, len(df.columns))))

# %%
df_port = df_port.div(df_port.sum(axis=1), axis=0)

# %% [markdown]
# ## Calculates metrics per portfolio
# - Returns as sum of returns times weight
# - Volatilty
# - Sharpe Ratio

# %%
def calc_risk(row):
    risk = np.sqrt(np.dot(row.T,np.dot(df.cov()*252, row)))
    return risk

# %%
vol = df_port.apply(calc_risk,axis=1)

# %%
ret = (df.describe().loc['mean'] * df_port).sum(axis=1)

# %%
df_port['Volatility'] = vol
df_port['Returns'] =  ret
df_port['Sharpe'] = ret/vol

# %%
df_port
# Out:
#        DowJones_Close  Gold_Close  Ibovespa_Close  IFIX_Close  S&P_Close  \
# 0            0.141993    0.118452        0.147591    0.180043   0.114898
# 1            0.190085    0.132750        0.179661    0.133030   0.132923
# 2            0.082513    0.142157        0.119044    0.187124   0.124420
# 3            0.151281    0.165560        0.092913    0.135771   0.167672
# 4            0.116568    0.129747        0.116523    0.221202   0.141614
# ...               ...         ...             ...         ...        ...
# 99995        0.226773    0.095966        0.140138    0.055783   0.194325
# 99996        0.175689    0.097162        0.100620    0.197458   0.142742
# 99997        0.213892    0.056620        0.096877    0.145515   0.189703
# 99998        0.099214    0.148325        0.158587    0.166749   0.126498
# 99999        0.131346    0.213786        0.123159    0.113975   0.111495
#
#        USDBRL_Close  selic_Close  Volatility   Returns    Sharpe
# 0          0.114898     0.182125    0.123216  1.000574  8.120504
# 1          0.165727     0.065824    0.151598  1.000677  6.600877
# 2          0.098550     0.246192    0.108188  1.000524  9.247973
# 3          0.106240     0.180562    0.134671  1.000619  7.430081
# 4          0.097071     0.177277    0.119062  1.000575  8.403797
# ...             ...          ...         ...       ...       ...
# 99995      0.143957     0.143059    0.159499  1.000674  6.273838
# 99996      0.153552     0.132778    0.133311  1.000615  7.505864
# 99997      0.150843     0.146551    0.146433  1.000638  6.833404
# 99998      0.138510     0.162117    0.124497  1.000585  8.037029
# 99999      0.153454     0.152785    0.134856  1.000620  7.419907
#
# [100000 rows x 10 columns]

# %%
plt.figure(figsize=(12,8))
plt.scatter(df_port['Volatility'], df_port['Returns'] , c=df_port['Sharpe'], cmap='viridis')
plt.colorbar(label='Sharpe Ratio')
plt.xlabel('Volatility')
plt.ylabel('Return')
plt.scatter(df_port.loc[df_port['Sharpe'] == df_port['Sharpe'].max(), 'Volatility'], df_port.loc[df_port['Sharpe'] == df_port['Sharpe'].max(), 'Returns'],c='red', s=50) # red dot
plt.show()
